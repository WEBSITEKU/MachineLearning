# %%
# Import necessary libraries
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# %%
# Load the iris dataset
iris = load_iris()
X = iris.data
y = iris.target

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Initialize the Decision Tree model
model = DecisionTreeClassifier(random_state=42)

# %%
# Train the model on the training data
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# Make predictions on the test data
y_pred = model.predict(X_test)

# %%
# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 1.00

# %%
# Print classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
# Print confusion matrix
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]

# %%
# Plot the decision tree
plt.figure(figsize=(12, 8))
plot_tree(model, feature_names=iris.feature_names, class_names=iris.target_names, filled=True)
plt.title("Decision Tree trained on the Iris dataset")
plt.show()

# %% [markdown]
# Penjelasan
# Impor Library:
#
# load_iris untuk memuat dataset iris.
# train_test_split untuk membagi dataset menjadi training dan test set.
# DecisionTreeClassifier untuk membuat model Decision Tree.
# accuracy_score, classification_report, dan confusion_matrix untuk evaluasi model.
# matplotlib.pyplot dan plot_tree untuk memvisualisasikan pohon keputusan.
# Memuat Dataset:
#
# Dataset iris dimuat menggunakan load_iris().
# X berisi fitur (data) dan y berisi label (target).
# Membagi Dataset:
#
# Dataset dibagi menjadi training set (70%) dan test set (30%) menggunakan train_test_split.
# random_state=42 digunakan untuk memastikan hasil pembagian yang konsisten.
# Inisialisasi dan Pelatihan Model:
#
# Model Decision Tree diinisialisasi dengan random_state=42 untuk hasil yang dapat direproduksi.
# Model dilatih menggunakan data pelatihan (X_train, y_train).
# Prediksi dan Evaluasi:
#
# Prediksi dibuat pada data pengujian (X_test).
# Akurasi model dihitung menggunakan accuracy_score.
# Laporan klasifikasi (classification_report) dan matriks kebingungan (confusion_matrix) dicetak untuk evaluasi yang lebih mendalam.
# Visualisasi:
#
# Pohon keputusan divisualisasikan menggunakan plot_tree.

# %% [markdown]
# Ketika kode dijalankan, output yang dihasilkan akan mencakup akurasi model, laporan klasifikasi, matriks kebingungan, dan visualisasi pohon keputusan.
# Visualisasi pohon keputusan akan ditampilkan dalam jendela plot Matplotlib dan menampilkan struktur pohon dengan pembagian fitur dan keputusan di setiap node.
